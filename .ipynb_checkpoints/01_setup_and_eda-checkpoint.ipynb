# %% [markdown]
# # Phase 1: Setup and Date Loading (MySQL Implementation)
#
# This notebook loads the 9 raw Olist CSVs into a local MySQL database, creating the foundation tables for downstream analysis. The downstream construction of `fact_orders` is implemented entirely in SQL and is located in `sql/01_fact_table.sql`. This file is executed directly in MySQL Workbench rather than through this notebook.
#
# **Why this approach:** The pandas implementation of Phase 1 was built first (preserved in `archive`), but the MySQL pipeline became the primary production approach because:
# 1. `fact_orders` is the input to all downstream analytical notebooks
# 2. SQL-based aggregation is faster and more reproducible than pandas chaining for tables of this size
# 3. Power BI connects directly to MySQL, removing a serialisation step
#
# **Outputs produced:**
# - 9 raw tables in MySQL: `customers`, `geolocation`, `order_items`, `order_payments`, `order_reviews`, `orders`, `products`, `sellers`, `category_translation`
# - These tables are then consumed by `sql/01_fact_table.sql` to build the analytical fact table
#
# **Key sanity numbers (after CSV loading):**
# - 9 tables loaded successfully
# - ~1.4M total rows across all tables
# - Largest table: `geolocation` (~1M rows)
# - Main analytical anchor: `orders` (~99K rows)

# %%
from sqlalchemy import create_engine, text
import pandas as pd
import os

USER = 'root'
PASSWORD = os.getenv('MYSQL_PASSWORD', 'YOUR_PASSWORD')
HOST = 'localhost'
PORT = 3306
DB = 'olist'

engine = create_engine(f'mysql+pymysql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}')

with engine.connect() as conn:
    result = conn.execute(text('SELECT VERSION()')).fetchone()
    print('Connected to MySQL:', result[0])
# Out:
# Connected to MySQL: 8.0.46

# %% [markdown]
# ## Loading the 9 raw CSVs
#
# Each CSV is loaded into pandas, type-mapped to appropriate SQL types, then written to MySQL via `to_sql`. The `build_dtype_map` function maps object columns to `VARCHAR(50)`, `VARCHAR(255)`, or `TEXT` based on observed string length. This avoids the default pandas-to-sql behaviour of converting all object columns to `TEXT`, which would prevent indexing on key columns and make downstream joins slow.
#
# Date columns are parsed explicitly via `parse_dates` to preserve datetime types end-to-end.

# %%
from sqlalchemy.types import VARCHAR, TEXT
import time

data_path = './data/raw/'
order_date_cols = [
    'order_purchase_timestamp', 'order_approved_at',
    'order_delivered_carrier_date', 'order_delivered_customer_date',
    'order_estimated_delivery_date'
]

table_specs = {
    'customers':            ('olist_customers_dataset.csv', None),
    'geolocation':          ('olist_geolocation_dataset.csv', None),
    'order_items':          ('olist_order_items_dataset.csv', ['shipping_limit_date']),
    'order_payments':       ('olist_order_payments_dataset.csv', None),
    'order_reviews':        ('olist_order_reviews_dataset.csv',
                             ['review_creation_date', 'review_answer_timestamp']),
    'orders':               ('olist_orders_dataset.csv', order_date_cols),
    'products':             ('olist_products_dataset.csv', None),
    'sellers':              ('olist_sellers_dataset.csv', None),
    'category_translation': ('product_category_name_translation.csv', None),
}

def build_dtype_map(df):
    dtype_map = {}
    for col in df.select_dtypes('object').columns:
        # Calculate max length seen in this column (NaN-safe)
        max_len = df[col].astype(str).str.len().max()
        if pd.isna(max_len) or max_len <= 50:
            dtype_map[col] = VARCHAR(50)
        elif max_len <= 255:
            dtype_map[col] = VARCHAR(255)
        else:
            dtype_map[col] = TEXT
    return dtype_map

for table_name, (file_name, date_cols) in table_specs.items():
    start = time.time()
    df = pd.read_csv(data_path + file_name, parse_dates=date_cols)
    dtype_map = build_dtype_map(df)
    df.to_sql(table_name, engine, if_exists='replace', index=False,
              chunksize=5000, dtype=dtype_map)
    elapsed = time.time() - start
    print(f"Loaded {table_name:25s} ({len(df):>8,} rows) in {elapsed:.1f}s")

print("\nDone.")
# Out:
# Loaded customers                 (  99,441 rows) in 2.0s
# Loaded geolocation               (1,000,163 rows) in 13.0s
# Loaded order_items               ( 112,650 rows) in 2.8s
# Loaded order_payments            ( 103,886 rows) in 1.7s
# Loaded order_reviews             (  99,224 rows) in 2.1s
# Loaded orders                    (  99,441 rows) in 2.7s
# Loaded products                  (  32,951 rows) in 0.7s
# Loaded sellers                   (   3,095 rows) in 0.1s
# Loaded category_translation      (      71 rows) in 0.0s
#
# Done.

# %% [markdown]
# ## Next steps
#
# With raw tables loaded, the next step is to construct `fact_orders` by joining and aggregating these tables. That construction is implemented in `sql/01_fact_table.sql` and is executed in MySQL Workbench.
#
# The `fact_orders` table becomes the input to:
# - `02_customer_analytics.ipynb` (RFM, CLV, cohort retention)
# - `03_category_performance.ipynb` (category quadrant analysis)
# - `04_operations_experience.ipynb` (delivery, geographic, retention)
